# %%
import os
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.applications import ResNet101V2

# %%
# Load CSV file with image labels
data_path = r"E:\Junaed_Jibon\Model_Training\updated_train_dataset.csv"
image_dir = r"E:\Junaed_Jibon\Model_Training\Train_images"

# %%
# Load and preprocess the dataset
data = pd.read_csv(data_path)
data['file_path'] = data['Image_Id'].apply(lambda x: os.path.join(image_dir, x))
data['label'] = data['Label'].astype(str)

# %%
# Parameters
img_height, img_width = 224, 224  # Image dimensions
batch_size = 32
epochs = 25

# %%
# Prepare Image Data Generator
data_gen = ImageDataGenerator(
    rescale=1.0 / 255,
    validation_split=0.1111
)

train_gen = data_gen.flow_from_dataframe(
    dataframe=data,
    directory=image_dir,
    x_col='file_path',
    y_col='label',
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

val_gen = data_gen.flow_from_dataframe(
    dataframe=data,
    directory=image_dir,
    x_col='file_path',
    y_col='label',
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 4151 validated image filenames belonging to 8 classes.
# Found 518 validated image filenames belonging to 8 classes.

# %%
# Load VGG19 model with pretrained weights and exclude top layer
base_model = ResNet101V2(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

# %%
# Add custom classification layers
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
out = Dense(8, activation='softmax')(x)  # Adjust output layer for 8 classes

model = Model(inputs=base_model.input, outputs=out)

# %%
# Create the complete model
model = Model(inputs=base_model.input, outputs=out)

# %%
# Compile the model with a slightly lower learning rate
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Add callbacks for dynamic learning rate adjustment and early stopping
callbacks = [
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=3,
        verbose=1
    ),
    EarlyStopping(
        monitor='val_loss',
        patience=4,
        verbose=1,
        restore_best_weights=True
    )
]

# %%
# Train the model
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=epochs,
    steps_per_epoch=train_gen.samples // batch_size,
    validation_steps=val_gen.samples // batch_size,
    callbacks=callbacks
)
# Out:
# Epoch 1/25
# 129/129 [==============================] - 67s 443ms/step - loss: 1.9651 - accuracy: 0.2688 - val_loss: 1.5469 - val_accuracy: 0.4766 - lr: 1.0000e-05
# Epoch 2/25
# 129/129 [==============================] - 55s 422ms/step - loss: 1.2678 - accuracy: 0.5890 - val_loss: 1.0078 - val_accuracy: 0.6816 - lr: 1.0000e-05
# Epoch 3/25
# 129/129 [==============================] - 54s 419ms/step - loss: 0.8390 - accuracy: 0.7543 - val_loss: 0.6819 - val_accuracy: 0.7930 - lr: 1.0000e-05
# Epoch 4/25
# 129/129 [==============================] - 55s 424ms/step - loss: 0.5498 - accuracy: 0.8575 - val_loss: 0.5034 - val_accuracy: 0.8320 - lr: 1.0000e-05
# Epoch 5/25
# 129/129 [==============================] - 55s 424ms/step - loss: 0.3483 - accuracy: 0.9218 - val_loss: 0.3844 - val_accuracy: 0.8770 - lr: 1.0000e-05
# Epoch 6/25
# 129/129 [==============================] - 55s 425ms/step - loss: 0.2306 - accuracy: 0.9522 - val_loss: 0.3084 - val_accuracy: 0.8906 - lr: 1.0000e-05
# Epoch 7/25
# 129/129 [==============================] - 55s 426ms/step - loss: 0.1590 - accuracy: 0.9711 - val_loss: 0.2469 - val_accuracy: 0.9180 - lr: 1.0000e-05
# Epoch 8/25
# 129/129 [==============================] - 55s 426ms/step - loss: 0.1009 - accuracy: 0.9825 - val_loss: 0.2269 - val_accuracy: 0.9316 - lr: 1.0000e-05
# Epoch 9/25
# 129/129 [==============================] - 55s 422ms/step - loss: 0.0717 - accuracy: 0.9913 - val_loss: 0.1959 - val_accuracy: 0.9355 - lr: 1.0000e-05
# Epoch 10/25
# 129/129 [==============================] - 55s 424ms/step - loss: 0.0516 - accuracy: 0.9939 - val_loss: 0.1770 - val_accuracy: 0.9434 - lr: 1.0000e-05
# Epoch 11/25
# 129/129 [==============================] - 55s 423ms/step - loss: 0.0407 - accuracy: 0.9947 - val_loss: 0.1705 - val_accuracy: 0.9453 - lr: 1.0000e-05
# Epoch 12/25
# 129/129 [==============================] - 55s 423ms/step - loss: 0.0267 - accuracy: 0.9973 - val_loss: 0.1577 - val_accuracy: 0.9512 - lr: 1.0000e-05
# Epoch 13/25
# 129/129 [==============================] - 55s 426ms/step - loss: 0.0234 - accuracy: 0.9978 - val_loss: 0.1527 - val_accuracy: 0.9512 - lr: 1.0000e-05
# Epoch 14/25
# 129/129 [==============================] - 55s 424ms/step - loss: 0.0189 - accuracy: 0.9973 - val_loss: 0.1401 - val_accuracy: 0.9531 - lr: 1.0000e-05
# Epoch 15/25
# 129/129 [==============================] - 55s 423ms/step - loss: 0.0169 - accuracy: 0.9988 - val_loss: 0.1476 - val_accuracy: 0.9531 - lr: 1.0000e-05
# Epoch 16/25
# 129/129 [==============================] - 55s 422ms/step - loss: 0.0142 - accuracy: 0.9981 - val_loss: 0.1373 - val_accuracy: 0.9590 - lr: 1.0000e-05
# Epoch 17/25
# 129/129 [==============================] - 55s 421ms/step - loss: 0.0100 - accuracy: 0.9993 - val_loss: 0.1391 - val_accuracy: 0.9629 - lr: 1.0000e-05
# Epoch 18/25
# 129/129 [==============================] - 55s 423ms/step - loss: 0.0087 - accuracy: 0.9998 - val_loss: 0.1389 - val_accuracy: 0.9570 - lr: 1.0000e-05
# Epoch 19/25
# 129/129 [==============================] - 55s 425ms/step - loss: 0.0066 - accuracy: 0.9993 - val_loss: 0.1317 - val_accuracy: 0.9570 - lr: 1.0000e-05
# Epoch 20/25
# 129/129 [==============================] - 55s 422ms/step - loss: 0.0060 - accuracy: 0.9993 - val_loss: 0.1251 - val_accuracy: 0.9570 - lr: 1.0000e-05
# Epoch 21/25
# 129/129 [==============================] - 55s 422ms/step - loss: 0.0069 - accuracy: 0.9993 - val_loss: 0.1276 - val_accuracy: 0.9609 - lr: 1.0000e-05
# Epoch 22/25
# 129/129 [==============================] - 55s 421ms/step - loss: 0.0078 - accuracy: 0.9985 - val_loss: 0.1381 - val_accuracy: 0.9473 - lr: 1.0000e-05
# Epoch 23/25
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 129/129 [==============================] - 55s 423ms/step - loss: 0.0066 - accuracy: 0.9985 - val_loss: 0.1262 - val_accuracy: 0.9492 - lr: 1.0000e-05
# Epoch 24/25
# 129/129 [==============================] - 55s 423ms/step - loss: 0.0059 - accuracy: 0.9990 - val_loss: 0.1239 - val_accuracy: 0.9531 - lr: 5.0000e-06
# Epoch 25/25
# 129/129 [==============================] - 55s 427ms/step - loss: 0.0060 - accuracy: 0.9988 - val_loss: 0.1224 - val_accuracy: 0.9570 - lr: 5.0000e-06

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_loss(history):
    # Check if history object is valid
    epochs = range(1, len(history.history['loss']) + 1)
    
    plt.figure(figsize=(6, 3))  # More horizontal layout
    
    # Plot loss curves
    plt.plot(epochs, np.array(history.history['loss']), label='Training Loss', 
             color='blue', linestyle='-', linewidth=1)
    
    if 'val_loss' in history.history:
        plt.plot(epochs, np.array(history.history['val_loss']), label='Validation Loss', 
                 color='red', linestyle='-', linewidth=1)

    plt.title('Training and Validation Loss', fontsize=12)
    plt.xlabel('Epochs', fontsize=10)
    plt.ylabel('Loss', fontsize=10)
    plt.legend(fontsize=10, loc='upper right')
    plt.grid(linestyle='dotted', alpha=0.6)

    # Dynamically adjust x-axis ticks
    interval = 2 if len(epochs) <= 50 else 5
    plt.xticks(range(1, len(epochs) + 1, interval), fontsize=8)
    
    # Set y-axis dynamically based on loss values
    min_loss = min(min(history.history['loss']), min(history.history.get('val_loss', [float('inf')])))
    max_loss = max(max(history.history['loss']), max(history.history.get('val_loss', [-float('inf')])))
    plt.yticks(np.arange(min_loss, max_loss + 0.2, 0.2), fontsize=8)  

    plt.show()
    
plot_loss(history)

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_accuracy(history):

    epochs = range(1, len(history.history['accuracy']) + 1)
    
    plt.figure(figsize=(6, 3))  # More horizontal layout

    # Plot accuracy with a thin, smooth line to match your reference image
    plt.plot(epochs, np.array(history.history['accuracy']) * 100, label='Training Accuracy', 
             color='blue', linestyle='-', linewidth=1, alpha=0.8)
    
    if 'val_accuracy' in history.history:
        plt.plot(epochs, np.array(history.history['val_accuracy']) * 100, label='Validation Accuracy', 
                 color='red', linestyle='-', linewidth=1, alpha=0.8)

    # Labels and title
    plt.title('Training and Validation Accuracy', fontsize=12)
    plt.xlabel('Epochs', fontsize=10)
    plt.ylabel('Accuracy (%)', fontsize=10)
    plt.legend(fontsize=10, loc='lower right')  
    plt.grid(linestyle='dotted', alpha=0.5)  # Softer grid lines

    # Dynamically adjust x-axis ticks
    interval = 5 if len(epochs) > 50 else 2
    plt.xticks(range(1, len(epochs) + 1, interval), fontsize=8)
    
    # Set y-axis from 0 to 100 with smooth intervals
    plt.yticks(np.arange(0, 101, 10), fontsize=8)  

    plt.show()

# Call the function correctly (no extra spaces)
plot_accuracy(history)

# %%
# Evaluate the model
eval_result = model.evaluate(val_gen)
print(f"Validation Loss: {eval_result[0]}, Validation Accuracy: {eval_result[1]}")
# Out:
# 17/17 [==============================] - 6s 342ms/step - loss: 0.1214 - accuracy: 0.9575
# Validation Loss: 0.12138007581233978, Validation Accuracy: 0.9575289487838745

# %%
# Save the model
model.save('ResNet101V2_Model.h5')
